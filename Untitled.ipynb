# %% [markdown]
# # Breakdown of the day after
# ## The day is long, but year is short
# ### Today is Tuesday and Thursday night
#
# _[follow link] (C:\Users\OWNER\OneDrive\Documents\udemy free courses.docx)_

# %%
import spacy

nlp = spacy.load('en_core_web_sm')  # Load English model (other languages available)
text = "This is an example sentence for tokenization."
doc = nlp(text)
sentences = [sent.text for sent in doc.sents]  # Extract sentences as a list
print(sentences)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
